# %%
# Environment settings
# !pip install -U --pre tensorflow=="2.*"
# !pip install tf_slim
# !pip install pybind11
import tensorflow as tf
assert float(tf.__version__[:3]) >= 2.3
import pathlib
import os

# !git clone https://github.com/tensorflow/tensorflow/

# %%
# Download model
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v1_fpn_640x640_coco17_tpu-8.tar.gz
# !tar -xvzf ssd_mobilenet_v1_fpn_640x640_coco17_tpu-8.tar.gz

# %%
# !mkdir tensorboard
# %cd tensorflow/tensorflow/python/tools/
# !python import_pb_to_tensorboard.py --model_dir /content/ssd_mobilenet_v1_fpn_640x640_coco17_tpu-8/saved_model/ --log_dir /content/tensorboard/

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/tensorboard/
