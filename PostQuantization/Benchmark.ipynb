# %%
# !sudo apt install git-lfs
# !git clone https://github.com/epikjjh/Deep-Learning-Quantization
# %cd Deep-Learning-Quantization
# !git lfs pull

# %%
# !pip3 install https://dl.google.com/coral/python/tflite_runtime-2.1.0.post1-cp36-cp36m-linux_x86_64.whl?hl=ko

# %%
# %cd /content/Deep-Learning-Quantization/PostQuantization

# %%
# !python3 detect_image.py --model models/16_float.tflite --input images/grace_hopper.jpg --labels coco_labels.txt --output images/grace_hopper_16.jpg --type colab

# %%
# !python3 detect_image.py --model models/dynamic_model.tflite --input images/grace_hopper.jpg --labels coco_labels.txt --output images/grace_hopper_dynamic.jpg --type colab
